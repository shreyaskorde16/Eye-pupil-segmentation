# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/RAML/data'
# Out:
# images	labels

# %%
DATA_DIR = '/content/gdrive/My Drive/RAML/data'

# %%
import os
os.chdir('/content/gdrive/My Drive/RAML')

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8l-seg.pt')

model.train(data='/content/gdrive/My Drive/RAML/config.yaml', epochs = 100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# resume training

#from ultralytics import YOLO
#model = YOLO()
#model.resume(task='segment')
#resume(model ='/content/gdrive/My Drive/RAML/runs/segment/train/weights/best.pt')

# %%
import os
from ultralytics import YOLO


model_path = '/content/gdrive/My Drive/RAML/runs/segment/train/weights/best.pt'
model = YOLO(model_path)

# %% [markdown]
# ## Prediction

# %%
from ultralytics import YOLO
#model.predict(source='0', stream=True)
model.predict(source='/content/gdrive/My Drive/RAML/eye796.png', save=True, show=True, )
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/gdrive/My Drive/RAML/eye796.png: 640x480 1 eye, 85.2ms
# Speed: 1.5ms preprocess, 85.2ms inference, 22.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'eye'}
#  orig_img: array([[[ 92,  82, 154],
#          [ 92,  80, 152],
#          [ 94,  83, 152],
#          ...,
#          [182, 142, 214],
#          [186, 146, 218],
#          [192, 152, 224]],
#
#         [[ 94,  84, 156],
#          [ 94,  82, 154],
#          [ 94,  83, 152],
#          ...,
#          [187, 147, 219],
#          [187, 147, 219],
#          [188, 148, 220]],
#
#         [[ 94,  85, 154],
#          [ 97,  86, 155],
#          [ 96,  85, 153],
#          ...,
# ...
